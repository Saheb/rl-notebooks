# %% [markdown]
# # 🏎️ Notebook 11 — The Clone Army
# ### Distributed RL, Multiprocessing, & A3C
#
# **Series**: RL Notebook Series · Act IV — Engineering · Post 11 of 16
#
# ---
#
# ## The Wall of Time
#
# If you just finished fighting for your life to perfectly tune Notebook 10's Continuous PPO, you learned an important lesson about Deep Reinforcement Learning:
# **It requires a massive amount of data to learn physics.**
#
# In physics tasks, 5000 episodes could take anywhere from 10 minutes to an hour of pure *Wall-Clock Time* on a single CPU core. And that's just a simple 2D pendulum! Imagine trying to train a 3D robot arm to solve a Rubik's cube, or an agent playing Dota 2.
#
# If an environment takes `50ms` to step the physics engine, a single agent is physically bottlenecked. It can never gather more than 20 transitions per second. Your massively powerful GPU sits completely idle `90%` of the time waiting for that single CPU core to slowly tick the physics simulation forward.
#
# ## The Solution: The Clone Army (Distributed RL)
#
# If we have a processor with 16 cores, why not launch **16 environments simultaneously**? We can clone the Agent 16 times, hand each clone their own environment, and tell them to go play independently.
#
# Instead of collecting 1 trajectory per hour, we collect 16. We then merge all 16 trajectories together into one massive batch and hand it to the GPU to update the "Global Brain".
#
# This concept is the backbone of almost all modern State-of-the-Art RL algorithms.

# %% [markdown]
# ### 1. Asynchronous Updates (A3C)
# In DeepMind's original 2016 A3C paper (Asynchronous Advantage Actor-Critic), they introduced the concept of a true **Global Network**:
# 1. You create **1 Global Network** that sits on your main CPU thread.
# 2. You spawn **$N$ Worker Processes** on $N$ different CPU cores. Each Worker has its own environment AND its own personal copy of the neural network (Local Networks).
# 3. A Worker plays the game for `128` steps and calculates its PPO Loss.
# 4. Instead of updating its own weights, the Worker "pushes" its computed gradients asynchronously to the Global Network (like pushing code to GitHub).
# 5. The Global Network uses those gradients to update its Master Weights.
# 6. The Worker then "pulls" the newest Master Weights, overwriting its Local Network, and repeats.
#
# *Because it is Asynchronous, no worker ever waits for another worker to finish. Worker #4 might push its gradients 2 milliseconds later than Worker #7. They just constantly blast gradients at the Master brain independently!*
#
# ### 2. Synchronous Updates (A2C & Vectorized Environments)
# The code we will write in this notebook uses **Synchronous Updates** (A2C).
# Instead of independent workers pushing chaotic gradients at random intervals, we literally stack the 8 environments side-by-side into a neat matrix.
# 1. When `env.reset()` fires, it gives us a perfectly stacked array of 8 different starting states.
# 2. We pass all 8 states through our **single** Neural Network at exactly the same time.
# 3. The network spits out 8 different actions synchronously.
# 4. We wait for all 8 environments to finish stepping, collect the rewards, and step again.
#
# Vectorized environments are infinitely easier to write, less prone to crashing your computer, and provide massive, perfectly formatted batches of training data for the GPU to update on instantly!
#
# ### 3. IMPALA (Importance Weighted Actor-Learner Architecture)
# A3C was revolutionary, but shipping massive weight matrices around memory between cores was slow.
# DeepMind later introduced **IMPALA**. They completely decoupled the "Actors" from the "Learner":
# - 100s of **Actors** run entirely on cheap CPUs. They don't calculate gradients. They just take the current model, run the game blazingly fast, and stream the resulting `(State, Action, Reward)` observations through a highly compressed network pipe directly into a central Queue.
# - A single massive **Learner** (the GPU) just reads the Queue non-stop, mathematically correcting for the fact that the Actors are using slightly "older" versions of the model (called *V-Trace* off-policy correction), and updates the weights 24/7.
#
# This architecture trained AlphaStar (StarCraft II) and OpenAI Five (Dota 2)!

# %%
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
import time

# %matplotlib inline
plt.rcParams.update({'figure.figsize': (10, 6), 'axes.grid': True, 'grid.alpha': 0.3})

torch.manual_seed(42)
np.random.seed(42)

# %% [markdown]
# ## 2. Gymnasium's Vectorized Environments
#
# Implementing raw multiprocessing `pipes` and queues in Python is outside the scope of RL theory (and usually requires a heavy framework like `Ray.io` or `RLlib`).
#
# Thankfully, Gymnasium provides a brilliant wrapper called `gym.make_vec`.
# It automatically spawns $N$ background processes, hands each one a `CartPole-v1` environment, and wraps them all up to look like a single synchronized environment.
#
# When we call `env.reset()`, it returns an array of shape `(8, 4)` (8 pending games, 4 features each)!
# When we call `env.step([act1, act2...])`, we pass it a list of 8 actions, and it steps all 8 games instantaneously in parallel.

# %%
class PPOActorCritic(nn.Module):
    # Exactly the identical class from Notebook 09
    def __init__(self, state_dim, action_dim, hidden_dim=64):
        super(PPOActorCritic, self).__init__()
        self.fc1 = nn.Linear(state_dim, hidden_dim)
        self.actor_fc = nn.Linear(hidden_dim, action_dim)
        self.critic_fc = nn.Linear(hidden_dim, 1)
        
    def forward(self, state):
        x = torch.tanh(self.fc1(state))
        action_logits = self.actor_fc(x)
        action_probs = F.softmax(action_logits, dim=-1)
        state_value = self.critic_fc(x)
        return action_probs, state_value
    
    def evaluate(self, state, action):
        action_probs, state_value = self.forward(state)
        m = Categorical(action_probs)
        log_prob = m.log_prob(action)
        entropy = m.entropy()
        return log_prob, state_value, entropy

# %% [markdown]
# ## 3. The Vectorized PPO Loop
#
# Look incredibly closely at this loop. We no longer wait until an episode finishes (`done == True`).
# Instead, we just step all 8 clones exactly `steps_per_env` times (e.g. 128).
# If any of the 8 clones crash their cart halfway through, the vectorized environment **automatically resets** that specific clone and sends back the new `state`, completely completely transparently under the hood!
#
# This means we ALWAYS gather precisely $128 \times 8 = 1024$ perfectly formatted transitions every single loop, regardless of how good or bad the agents are performing.

# %%
def train_sync_vector_ppo(env_name="CartPole-v1", num_envs=8, total_timesteps=150_000, steps_per_env=128):
    # Launch 8 simultaneous worker environments using Python Multiprocessing via Gymnasium!
    envs = gym.make_vec(env_name, num_envs=num_envs)
    
    # Note: Vector env spaces are wrapped, so we explicitly pull the shape of the sub-environment
    state_dim = envs.single_observation_space.shape[0]
    action_dim = envs.single_action_space.n
    
    network = PPOActorCritic(state_dim, action_dim)
    optimizer = optim.Adam(network.parameters(), lr=2.5e-3, eps=1e-5)
    
    # We pre-allocate massive tensors to hold everything. This avoids slow Python lists.
    # Shape: (128 steps, 8 parallel clones, ...)
    obs = torch.zeros((steps_per_env, num_envs, state_dim))
    actions = torch.zeros((steps_per_env, num_envs))
    logprobs = torch.zeros((steps_per_env, num_envs))
    rewards = torch.zeros((steps_per_env, num_envs))
    dones = torch.zeros((steps_per_env, num_envs))
    values = torch.zeros((steps_per_env, num_envs))
    
    global_step = 0
    start_time = time.time()
    returns_tracker = []
    time_tracker = []
    ep_returns = np.zeros(num_envs)
    
    # Initial reset returns 8 starting states: Shape (8, 4)
    next_obs, _ = envs.reset(seed=42)
    next_obs = torch.Tensor(next_obs)
    next_done = torch.zeros(num_envs)
    
    num_updates = total_timesteps // (steps_per_env * num_envs)
    
    for update in range(1, num_updates + 1):
        # 1. Rollout Phase (The 8 Clones Play)
        for step in range(0, steps_per_env):
            global_step += num_envs
            obs[step] = next_obs
            dones[step] = next_done
            
            # Batch inference! The Actor calculates 8 actions instantaneously.
            with torch.no_grad():
                probs, value = network(next_obs)
                dist = Categorical(probs)
                action = dist.sample()
                logprob = dist.log_prob(action)
                
            values[step] = value.squeeze()
            actions[step] = action
            logprobs[step] = logprob
            
            # 8 environments execute 8 physical steps in parallel over multiprocessing pipes!
            next_obs_np, reward, terminated, truncated, infos = envs.step(action.numpy())
            
            # Handle raw data
            next_obs = torch.Tensor(next_obs_np)
            rewards[step] = torch.tensor(reward)
            next_done = torch.Tensor(terminated | truncated)
            
            ep_returns += reward
            for i in range(num_envs):
                if terminated[i] or truncated[i]:
                    returns_tracker.append(ep_returns[i])
                    time_tracker.append(time.time() - start_time)
                    ep_returns[i] = 0.0
                        
        # 2. Advantage Estimation (using Generalized Advantage Estimation GAE)
        with torch.no_grad():
            _, next_value = network(next_obs)
            next_value = next_value.squeeze()
            
            advantages = torch.zeros_like(rewards)
            lastgaelam = 0
            for t in reversed(range(steps_per_env)):
                if t == steps_per_env - 1:
                    nextnonterminal = 1.0 - next_done
                    nextvalues = next_value
                else:
                    nextnonterminal = 1.0 - dones[t + 1]
                    nextvalues = values[t + 1]
                delta = rewards[t] + 0.99 * nextvalues * nextnonterminal - values[t]
                advantages[t] = lastgaelam = delta + 0.99 * 0.95 * nextnonterminal * lastgaelam
            returns = advantages + values
            
        # 3. Flatten the batch: (128, 8, ...) becomes (1024, ...)
        b_obs = obs.reshape((-1, state_dim))
        b_logprobs = logprobs.reshape(-1)
        b_actions = actions.reshape(-1)
        b_advantages = advantages.reshape(-1)
        b_returns = returns.reshape(-1)
        
        # Normalize the advantages identically across all 8 clones
        b_advantages = (b_advantages - b_advantages.mean()) / (b_advantages.std() + 1e-8)
        
        # 4. Global Network Update (The standard PPO math!)
        for epoch in range(4):
            new_logprobs, new_value, entropy = network.evaluate(b_obs, b_actions)
            new_value = new_value.squeeze()
            
            logratio = new_logprobs - b_logprobs
            ratio = logratio.exp()
            
            pg_loss1 = b_advantages * ratio
            pg_loss2 = b_advantages * torch.clamp(ratio, 1 - 0.2, 1 + 0.2)
            pg_loss = torch.max(-pg_loss1, -pg_loss2).mean() # Negative because optimizer MINIMIZES loss
            
            v_loss = 0.5 * F.mse_loss(new_value, b_returns)
            ent_loss = entropy.mean()
            
            loss = pg_loss - 0.01 * ent_loss + v_loss
            
            optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(network.parameters(), 0.5)
            optimizer.step()
            
        if update % 5 == 0 and len(returns_tracker) > 0:
            avg_ret = np.mean(returns_tracker[-50:])
            fps = int(global_step / (time.time() - start_time))
            print(f"Update {update:3d} | Total Steps: {global_step:6d} | FPS: {fps:4d} | Avg Reward: {avg_ret:.1f}")
            
            if avg_ret >= 495.0:
                solve_time = time.time() - start_time
                print(f"\n\U0001f3af Solved in {solve_time:.1f} seconds at update {update}!")
                envs.close()
                return time_tracker, returns_tracker, solve_time

    envs.close()
    return time_tracker, returns_tracker, time.time() - start_time

# %% [markdown]
# ## 4. Launching the Clone Army
#
# Notice the **FPS (Frames Per Second)** printed on the right.
# Because 8 processes are stepping physics simultaneously, we collect data almost an order of magnitude faster. Time is no longer an insurmountable wall.

# %%
import time

print("Training 1 Clone...")
times_1, returns_1, solve_time_1 = train_sync_vector_ppo(num_envs=1, total_timesteps=400_000, steps_per_env=128)
      
print("\nTraining 8 Clones...")
times_8, returns_8, solve_time_8 = train_sync_vector_ppo(num_envs=8, total_timesteps=400_000, steps_per_env=128)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))

# Plot 1 Clone
ax1.plot(times_1, returns_1, color='#94a3b8', alpha=0.3)
window = 50
if len(returns_1) >= window:
    smoothed_1 = np.convolve(returns_1, np.ones(window)/window, mode='valid')
    ax1.plot(times_1[window-1:], smoothed_1, color='#475569', linewidth=2)
ax1.set_title(f"1 Worker (Solved in {solve_time_1:.1f}s)")
ax1.set_xlabel("Wall-Clock Time (seconds)")
ax1.set_xlim(0, max(solve_time_1, solve_time_8))
ax1.set_ylabel("Total Reward")
ax1.axhline(500, color='gray', linestyle='--', label="Solved")
ax1.set_ylim(0, 550)
ax1.legend()

# Plot 8 Clones
ax2.plot(times_8, returns_8, color='#f43f5e', alpha=0.3)
if len(returns_8) >= window:
    smoothed_8 = np.convolve(returns_8, np.ones(window)/window, mode='valid')
    ax2.plot(times_8[window-1:], smoothed_8, color='#e11d48', linewidth=2)

speedup = solve_time_1 / solve_time_8
ax2.set_title(f"8 Workers (Solved in {solve_time_8:.1f}s) - {speedup:.1f}x Faster!")
ax2.set_xlabel("Wall-Clock Time (seconds)")
ax2.set_xlim(0, max(solve_time_1, solve_time_8))
ax2.axhline(500, color='gray', linestyle='--', label="Solved")
ax2.set_ylim(0, 550)
ax2.legend()

plt.tight_layout()
plt.show()
# Out:
# Training 1 Clone...
# Update   5 | Total Steps:    640 | FPS: 2080 | Avg Reward: 29.3
# Update  10 | Total Steps:   1280 | FPS: 1221 | Avg Reward: 34.4
# Update  15 | Total Steps:   1920 | FPS: 1175 | Avg Reward: 38.1
# Update  20 | Total Steps:   2560 | FPS: 1394 | Avg Reward: 45.7
# Update  25 | Total Steps:   3200 | FPS: 1598 | Avg Reward: 53.9
# Update  30 | Total Steps:   3840 | FPS: 1758 | Avg Reward: 62.9
# Update  35 | Total Steps:   4480 | FPS: 1760 | Avg Reward: 69.9
# Update  40 | Total Steps:   5120 | FPS: 1672 | Avg Reward: 74.3
# Update  45 | Total Steps:   5760 | FPS: 1613 | Avg Reward: 78.9
# Update  50 | Total Steps:   6400 | FPS: 1595 | Avg Reward: 85.8
# Update  55 | Total Steps:   7040 | FPS: 1608 | Avg Reward: 86.2
# Update  60 | Total Steps:   7680 | FPS: 1628 | Avg Reward: 76.8
# Update  65 | Total Steps:   8320 | FPS: 1655 | Avg Reward: 70.6
# Update  70 | Total Steps:   8960 | FPS: 1721 | Avg Reward: 72.1
# Update  75 | Total Steps:   9600 | FPS: 1756 | Avg Reward: 74.1
# Update  80 | Total Steps:  10240 | FPS: 1706 | Avg Reward: 71.0
# Update  85 | Total Steps:  10880 | FPS: 1653 | Avg Reward: 68.4
# Update  90 | Total Steps:  11520 | FPS: 1697 | Avg Reward: 70.8
# Update  95 | Total Steps:  12160 | FPS: 1732 | Avg Reward: 79.9
# Update 100 | Total Steps:  12800 | FPS: 1781 | Avg Reward: 89.8
# Update 105 | Total Steps:  13440 | FPS: 1827 | Avg Reward: 92.9
# Update 110 | Total Steps:  14080 | FPS: 1872 | Avg Reward: 88.8
# Update 115 | Total Steps:  14720 | FPS: 1915 | Avg Reward: 93.1
# Update 120 | Total Steps:  15360 | FPS: 1949 | Avg Reward: 94.2
# Update 125 | Total Steps:  16000 | FPS: 1933 | Avg Reward: 85.5
# Update 130 | Total Steps:  16640 | FPS: 1825 | Avg Reward: 87.3
# Update 135 | Total Steps:  17280 | FPS: 1765 | Avg Reward: 83.9
# Update 140 | Total Steps:  17920 | FPS: 1759 | Avg Reward: 87.7
# Update 145 | Total Steps:  18560 | FPS: 1778 | Avg Reward: 96.4
# Update 150 | Total Steps:  19200 | FPS: 1802 | Avg Reward: 102.0
# Update 155 | Total Steps:  19840 | FPS: 1776 | Avg Reward: 104.4
# Update 160 | Total Steps:  20480 | FPS: 1722 | Avg Reward: 103.3
# Update 165 | Total Steps:  21120 | FPS: 1716 | Avg Reward: 106.0
# Update 170 | Total Steps:  21760 | FPS: 1742 | Avg Reward: 118.4
# Update 175 | Total Steps:  22400 | FPS: 1765 | Avg Reward: 120.1
# Update 180 | Total Steps:  23040 | FPS: 1792 | Avg Reward: 120.4
# Update 185 | Total Steps:  23680 | FPS: 1819 | Avg Reward: 114.8
# Update 190 | Total Steps:  24320 | FPS: 1845 | Avg Reward: 109.4
# Update 195 | Total Steps:  24960 | FPS: 1870 | Avg Reward: 116.1
# Update 200 | Total Steps:  25600 | FPS: 1832 | Avg Reward: 120.9
# Update 205 | Total Steps:  26240 | FPS: 1805 | Avg Reward: 119.2
# Update 210 | Total Steps:  26880 | FPS: 1801 | Avg Reward: 119.6
# Update 215 | Total Steps:  27520 | FPS: 1789 | Avg Reward: 133.2
# Update 220 | Total Steps:  28160 | FPS: 1810 | Avg Reward: 142.9
# Update 225 | Total Steps:  28800 | FPS: 1830 | Avg Reward: 130.0
# Update 230 | Total Steps:  29440 | FPS: 1849 | Avg Reward: 130.5
# Update 235 | Total Steps:  30080 | FPS: 1870 | Avg Reward: 137.4
# Update 240 | Total Steps:  30720 | FPS: 1890 | Avg Reward: 136.6
# Update 245 | Total Steps:  31360 | FPS: 1910 | Avg Reward: 131.4
# Update 250 | Total Steps:  32000 | FPS: 1923 | Avg Reward: 134.4
# Update 255 | Total Steps:  32640 | FPS: 1933 | Avg Reward: 138.7
# Update 260 | Total Steps:  33280 | FPS: 1949 | Avg Reward: 122.3
# Update 265 | Total Steps:  33920 | FPS: 1966 | Avg Reward: 123.9
# Update 270 | Total Steps:  34560 | FPS: 1977 | Avg Reward: 123.0
# Update 275 | Total Steps:  35200 | FPS: 1989 | Avg Reward: 119.4
# Update 280 | Total Steps:  35840 | FPS: 2004 | Avg Reward: 114.1
# Update 285 | Total Steps:  36480 | FPS: 2021 | Avg Reward: 120.4
# Update 290 | Total Steps:  37120 | FPS: 2023 | Avg Reward: 130.9
# Update 295 | Total Steps:  37760 | FPS: 2036 | Avg Reward: 125.1
# Update 300 | Total Steps:  38400 | FPS: 2012 | Avg Reward: 123.8
# Update 305 | Total Steps:  39040 | FPS: 2012 | Avg Reward: 125.2
# Update 310 | Total Steps:  39680 | FPS: 2023 | Avg Reward: 132.8
# Update 315 | Total Steps:  40320 | FPS: 1974 | Avg Reward: 144.1
# Update 320 | Total Steps:  40960 | FPS: 1984 | Avg Reward: 152.1
# Update 325 | Total Steps:  41600 | FPS: 1995 | Avg Reward: 151.7
# Update 330 | Total Steps:  42240 | FPS: 2010 | Avg Reward: 154.6
# Update 335 | Total Steps:  42880 | FPS: 2025 | Avg Reward: 163.3
# Update 340 | Total Steps:  43520 | FPS: 2039 | Avg Reward: 172.7
# Update 345 | Total Steps:  44160 | FPS: 2054 | Avg Reward: 180.4
# Update 350 | Total Steps:  44800 | FPS: 2068 | Avg Reward: 163.8
# Update 355 | Total Steps:  45440 | FPS: 2082 | Avg Reward: 154.0
# Update 360 | Total Steps:  46080 | FPS: 2095 | Avg Reward: 160.3
# Update 365 | Total Steps:  46720 | FPS: 2109 | Avg Reward: 169.9
# Update 370 | Total Steps:  47360 | FPS: 2107 | Avg Reward: 127.6
# Update 375 | Total Steps:  48000 | FPS: 2116 | Avg Reward: 122.5
# Update 380 | Total Steps:  48640 | FPS: 2116 | Avg Reward: 125.9
# Update 385 | Total Steps:  49280 | FPS: 2079 | Avg Reward: 121.3
# Update 390 | Total Steps:  49920 | FPS: 2048 | Avg Reward: 106.9
# Update 395 | Total Steps:  50560 | FPS: 2058 | Avg Reward: 116.5
# Update 400 | Total Steps:  51200 | FPS: 2067 | Avg Reward: 122.9
# Update 405 | Total Steps:  51840 | FPS: 2079 | Avg Reward: 137.4
# Update 410 | Total Steps:  52480 | FPS: 2091 | Avg Reward: 150.4
# Update 415 | Total Steps:  53120 | FPS: 2103 | Avg Reward: 157.7
# Update 420 | Total Steps:  53760 | FPS: 2114 | Avg Reward: 144.2
# Update 425 | Total Steps:  54400 | FPS: 2126 | Avg Reward: 148.9
# Update 430 | Total Steps:  55040 | FPS: 2137 | Avg Reward: 156.7
# Update 435 | Total Steps:  55680 | FPS: 2148 | Avg Reward: 139.7
# Update 440 | Total Steps:  56320 | FPS: 2158 | Avg Reward: 130.7
# Update 445 | Total Steps:  56960 | FPS: 2167 | Avg Reward: 139.9
# Update 450 | Total Steps:  57600 | FPS: 2174 | Avg Reward: 148.5
# Update 455 | Total Steps:  58240 | FPS: 2184 | Avg Reward: 154.4
# Update 460 | Total Steps:  58880 | FPS: 2194 | Avg Reward: 141.1
# Update 465 | Total Steps:  59520 | FPS: 2204 | Avg Reward: 113.6
# Update 470 | Total Steps:  60160 | FPS: 2213 | Avg Reward: 115.3
# Update 475 | Total Steps:  60800 | FPS: 2224 | Avg Reward: 123.3
# Update 480 | Total Steps:  61440 | FPS: 2234 | Avg Reward: 128.1
# Update 485 | Total Steps:  62080 | FPS: 2243 | Avg Reward: 139.5
# Update 490 | Total Steps:  62720 | FPS: 2253 | Avg Reward: 145.7
# Update 495 | Total Steps:  63360 | FPS: 2262 | Avg Reward: 155.1
# Update 500 | Total Steps:  64000 | FPS: 2269 | Avg Reward: 169.9
# Update 505 | Total Steps:  64640 | FPS: 2276 | Avg Reward: 181.3
# Update 510 | Total Steps:  65280 | FPS: 2284 | Avg Reward: 187.8
# Update 515 | Total Steps:  65920 | FPS: 2293 | Avg Reward: 193.4
# Update 520 | Total Steps:  66560 | FPS: 2302 | Avg Reward: 212.2
# Update 525 | Total Steps:  67200 | FPS: 2311 | Avg Reward: 221.7
# Update 530 | Total Steps:  67840 | FPS: 2320 | Avg Reward: 230.0
# Update 535 | Total Steps:  68480 | FPS: 2321 | Avg Reward: 211.0
# Update 540 | Total Steps:  69120 | FPS: 2325 | Avg Reward: 208.4
# Update 545 | Total Steps:  69760 | FPS: 2333 | Avg Reward: 216.0
# Update 550 | Total Steps:  70400 | FPS: 2339 | Avg Reward: 226.9
# Update 555 | Total Steps:  71040 | FPS: 2339 | Avg Reward: 239.1
# Update 560 | Total Steps:  71680 | FPS: 2343 | Avg Reward: 246.9
# Update 565 | Total Steps:  72320 | FPS: 2351 | Avg Reward: 253.7
# Update 570 | Total Steps:  72960 | FPS: 2359 | Avg Reward: 229.6
# Update 575 | Total Steps:  73600 | FPS: 2368 | Avg Reward: 218.1
# Update 580 | Total Steps:  74240 | FPS: 2376 | Avg Reward: 190.4
# Update 585 | Total Steps:  74880 | FPS: 2384 | Avg Reward: 184.6
# Update 590 | Total Steps:  75520 | FPS: 2392 | Avg Reward: 179.7
# Update 595 | Total Steps:  76160 | FPS: 2400 | Avg Reward: 171.7
# Update 600 | Total Steps:  76800 | FPS: 2407 | Avg Reward: 170.8
# Update 605 | Total Steps:  77440 | FPS: 2413 | Avg Reward: 184.5
# Update 610 | Total Steps:  78080 | FPS: 2418 | Avg Reward: 191.9
# Update 615 | Total Steps:  78720 | FPS: 2423 | Avg Reward: 193.4
# Update 620 | Total Steps:  79360 | FPS: 2431 | Avg Reward: 198.4
# Update 625 | Total Steps:  80000 | FPS: 2438 | Avg Reward: 197.9
# Update 630 | Total Steps:  80640 | FPS: 2445 | Avg Reward: 129.5
# Update 635 | Total Steps:  81280 | FPS: 2452 | Avg Reward: 20.9
# Update 640 | Total Steps:  81920 | FPS: 2459 | Avg Reward: 29.8
# Update 645 | Total Steps:  82560 | FPS: 2466 | Avg Reward: 41.6
# Update 650 | Total Steps:  83200 | FPS: 2473 | Avg Reward: 52.3
# Update 655 | Total Steps:  83840 | FPS: 2479 | Avg Reward: 61.7
# Update 660 | Total Steps:  84480 | FPS: 2484 | Avg Reward: 75.0
# Update 665 | Total Steps:  85120 | FPS: 2487 | Avg Reward: 84.6
# Update 670 | Total Steps:  85760 | FPS: 2493 | Avg Reward: 94.1
# Update 675 | Total Steps:  86400 | FPS: 2499 | Avg Reward: 103.8
# Update 680 | Total Steps:  87040 | FPS: 2506 | Avg Reward: 123.1
# Update 685 | Total Steps:  87680 | FPS: 2512 | Avg Reward: 129.2
# Update 690 | Total Steps:  88320 | FPS: 2518 | Avg Reward: 145.5
# Update 695 | Total Steps:  88960 | FPS: 2524 | Avg Reward: 154.4
# Update 700 | Total Steps:  89600 | FPS: 2531 | Avg Reward: 158.2
# Update 705 | Total Steps:  90240 | FPS: 2537 | Avg Reward: 164.2
# Update 710 | Total Steps:  90880 | FPS: 2542 | Avg Reward: 171.9
# Update 715 | Total Steps:  91520 | FPS: 2546 | Avg Reward: 187.0
# Update 720 | Total Steps:  92160 | FPS: 2549 | Avg Reward: 196.6
# Update 725 | Total Steps:  92800 | FPS: 2555 | Avg Reward: 204.4
# Update 730 | Total Steps:  93440 | FPS: 2561 | Avg Reward: 218.2
# Update 735 | Total Steps:  94080 | FPS: 2567 | Avg Reward: 221.4
# Update 740 | Total Steps:  94720 | FPS: 2573 | Avg Reward: 225.2
# Update 745 | Total Steps:  95360 | FPS: 2579 | Avg Reward: 240.7
# Update 750 | Total Steps:  96000 | FPS: 2585 | Avg Reward: 248.6
# Update 755 | Total Steps:  96640 | FPS: 2591 | Avg Reward: 259.4
# Update 760 | Total Steps:  97280 | FPS: 2596 | Avg Reward: 268.6
# Update 765 | Total Steps:  97920 | FPS: 2600 | Avg Reward: 273.7
# Update 770 | Total Steps:  98560 | FPS: 2602 | Avg Reward: 280.4
# Update 775 | Total Steps:  99200 | FPS: 2606 | Avg Reward: 291.9
# Update 780 | Total Steps:  99840 | FPS: 2611 | Avg Reward: 291.9
# Update 785 | Total Steps: 100480 | FPS: 2617 | Avg Reward: 289.9
# Update 790 | Total Steps: 101120 | FPS: 2622 | Avg Reward: 289.9
# Update 795 | Total Steps: 101760 | FPS: 2628 | Avg Reward: 286.3
# Update 800 | Total Steps: 102400 | FPS: 2633 | Avg Reward: 281.3
# Update 805 | Total Steps: 103040 | FPS: 2638 | Avg Reward: 294.1
# Update 810 | Total Steps: 103680 | FPS: 2643 | Avg Reward: 303.8
# Update 815 | Total Steps: 104320 | FPS: 2647 | Avg Reward: 313.1
# Update 820 | Total Steps: 104960 | FPS: 2649 | Avg Reward: 326.0
# Update 825 | Total Steps: 105600 | FPS: 2651 | Avg Reward: 333.2
# Update 830 | Total Steps: 106240 | FPS: 2656 | Avg Reward: 342.5
# Update 835 | Total Steps: 106880 | FPS: 2661 | Avg Reward: 350.3
# Update 840 | Total Steps: 107520 | FPS: 2666 | Avg Reward: 360.2
# Update 845 | Total Steps: 108160 | FPS: 2671 | Avg Reward: 360.3
# Update 850 | Total Steps: 108800 | FPS: 2676 | Avg Reward: 354.7
# Update 855 | Total Steps: 109440 | FPS: 2680 | Avg Reward: 347.9
# Update 860 | Total Steps: 110080 | FPS: 2685 | Avg Reward: 351.4
# Update 865 | Total Steps: 110720 | FPS: 2690 | Avg Reward: 337.8
# Update 870 | Total Steps: 111360 | FPS: 2694 | Avg Reward: 346.9
# Update 875 | Total Steps: 112000 | FPS: 2696 | Avg Reward: 343.8
# Update 880 | Total Steps: 112640 | FPS: 2698 | Avg Reward: 343.8
# Update 885 | Total Steps: 113280 | FPS: 2702 | Avg Reward: 340.1
# Update 890 | Total Steps: 113920 | FPS: 2707 | Avg Reward: 336.2
# Update 895 | Total Steps: 114560 | FPS: 2712 | Avg Reward: 334.0
# Update 900 | Total Steps: 115200 | FPS: 2716 | Avg Reward: 335.8
# Update 905 | Total Steps: 115840 | FPS: 2721 | Avg Reward: 339.6
# Update 910 | Total Steps: 116480 | FPS: 2726 | Avg Reward: 315.1
# Update 915 | Total Steps: 117120 | FPS: 2730 | Avg Reward: 315.1
# Update 920 | Total Steps: 117760 | FPS: 2735 | Avg Reward: 315.1
# Update 925 | Total Steps: 118400 | FPS: 2736 | Avg Reward: 327.2
# Update 930 | Total Steps: 119040 | FPS: 2737 | Avg Reward: 326.6
# Update 935 | Total Steps: 119680 | FPS: 2739 | Avg Reward: 326.6
# Update 940 | Total Steps: 120320 | FPS: 2744 | Avg Reward: 335.5
# Update 945 | Total Steps: 120960 | FPS: 2743 | Avg Reward: 340.1
# Update 950 | Total Steps: 121600 | FPS: 2744 | Avg Reward: 335.6
# Update 955 | Total Steps: 122240 | FPS: 2749 | Avg Reward: 344.7
# Update 960 | Total Steps: 122880 | FPS: 2753 | Avg Reward: 347.0
# Update 965 | Total Steps: 123520 | FPS: 2757 | Avg Reward: 355.1
# Update 970 | Total Steps: 124160 | FPS: 2761 | Avg Reward: 351.2
# Update 975 | Total Steps: 124800 | FPS: 2764 | Avg Reward: 351.2
# Update 980 | Total Steps: 125440 | FPS: 2763 | Avg Reward: 360.4
# Update 985 | Total Steps: 126080 | FPS: 2766 | Avg Reward: 362.4
# Update 990 | Total Steps: 126720 | FPS: 2770 | Avg Reward: 368.1
# Update 995 | Total Steps: 127360 | FPS: 2774 | Avg Reward: 374.2
# Update 1000 | Total Steps: 128000 | FPS: 2778 | Avg Reward: 377.9
# Update 1005 | Total Steps: 128640 | FPS: 2782 | Avg Reward: 387.3
# Update 1010 | Total Steps: 129280 | FPS: 2786 | Avg Reward: 387.3
# Update 1015 | Total Steps: 129920 | FPS: 2790 | Avg Reward: 387.3
# Update 1020 | Total Steps: 130560 | FPS: 2793 | Avg Reward: 393.8
# Update 1025 | Total Steps: 131200 | FPS: 2796 | Avg Reward: 409.7
# Update 1030 | Total Steps: 131840 | FPS: 2798 | Avg Reward: 409.7
# Update 1035 | Total Steps: 132480 | FPS: 2800 | Avg Reward: 413.1
# Update 1040 | Total Steps: 133120 | FPS: 2804 | Avg Reward: 420.8
# Update 1045 | Total Steps: 133760 | FPS: 2808 | Avg Reward: 420.8
# Update 1050 | Total Steps: 134400 | FPS: 2812 | Avg Reward: 424.5
# Update 1055 | Total Steps: 135040 | FPS: 2815 | Avg Reward: 424.5
# Update 1060 | Total Steps: 135680 | FPS: 2819 | Avg Reward: 433.2
# Update 1065 | Total Steps: 136320 | FPS: 2823 | Avg Reward: 439.5
# Update 1070 | Total Steps: 136960 | FPS: 2826 | Avg Reward: 439.5
# Update 1075 | Total Steps: 137600 | FPS: 2830 | Avg Reward: 440.0
# Update 1080 | Total Steps: 138240 | FPS: 2832 | Avg Reward: 445.1
# Update 1085 | Total Steps: 138880 | FPS: 2834 | Avg Reward: 448.2
# Update 1090 | Total Steps: 139520 | FPS: 2835 | Avg Reward: 457.3
# Update 1095 | Total Steps: 140160 | FPS: 2838 | Avg Reward: 475.4
# Update 1100 | Total Steps: 140800 | FPS: 2841 | Avg Reward: 475.4
# Update 1105 | Total Steps: 141440 | FPS: 2844 | Avg Reward: 475.4
# Update 1110 | Total Steps: 142080 | FPS: 2847 | Avg Reward: 475.4
# Update 1115 | Total Steps: 142720 | FPS: 2851 | Avg Reward: 476.0
# Update 1120 | Total Steps: 143360 | FPS: 2854 | Avg Reward: 476.0
# Update 1125 | Total Steps: 144000 | FPS: 2858 | Avg Reward: 476.0
# Update 1130 | Total Steps: 144640 | FPS: 2860 | Avg Reward: 476.0
# Update 1135 | Total Steps: 145280 | FPS: 2862 | Avg Reward: 479.5
# Update 1140 | Total Steps: 145920 | FPS: 2864 | Avg Reward: 486.6
# Update 1145 | Total Steps: 146560 | FPS: 2866 | Avg Reward: 486.6
# Update 1150 | Total Steps: 147200 | FPS: 2870 | Avg Reward: 492.3
# Update 1155 | Total Steps: 147840 | FPS: 2862 | Avg Reward: 496.1
#
# 🎯 Solved in 51.6 seconds at update 1155!
#
# Training 8 Clones...
# Update   5 | Total Steps:   5120 | FPS: 14485 | Avg Reward: 39.3
# Update  10 | Total Steps:  10240 | FPS: 14614 | Avg Reward: 46.9
# Update  15 | Total Steps:  15360 | FPS: 13982 | Avg Reward: 59.5
# Update  20 | Total Steps:  20480 | FPS: 12920 | Avg Reward: 57.3
# Update  25 | Total Steps:  25600 | FPS: 13253 | Avg Reward: 79.7
# Update  30 | Total Steps:  30720 | FPS: 14462 | Avg Reward: 78.8
# Update  35 | Total Steps:  35840 | FPS: 15408 | Avg Reward: 78.6
# Update  40 | Total Steps:  40960 | FPS: 16277 | Avg Reward: 95.7
# Update  45 | Total Steps:  46080 | FPS: 16939 | Avg Reward: 64.3
# Update  50 | Total Steps:  51200 | FPS: 17419 | Avg Reward: 60.5
# Update  55 | Total Steps:  56320 | FPS: 17228 | Avg Reward: 75.2
# Update  60 | Total Steps:  61440 | FPS: 16989 | Avg Reward: 55.6
# Update  65 | Total Steps:  66560 | FPS: 17339 | Avg Reward: 68.7
# Update  70 | Total Steps:  71680 | FPS: 17800 | Avg Reward: 80.6
# Update  75 | Total Steps:  76800 | FPS: 18198 | Avg Reward: 88.8
# Update  80 | Total Steps:  81920 | FPS: 18572 | Avg Reward: 82.5
# Update  85 | Total Steps:  87040 | FPS: 18882 | Avg Reward: 82.9
# Update  90 | Total Steps:  92160 | FPS: 19112 | Avg Reward: 100.6
# Update  95 | Total Steps:  97280 | FPS: 19170 | Avg Reward: 94.6
# Update 100 | Total Steps: 102400 | FPS: 19293 | Avg Reward: 98.3
# Update 105 | Total Steps: 107520 | FPS: 19560 | Avg Reward: 100.1
# Update 110 | Total Steps: 112640 | FPS: 19790 | Avg Reward: 119.2
# Update 115 | Total Steps: 117760 | FPS: 19983 | Avg Reward: 141.8
# Update 120 | Total Steps: 122880 | FPS: 20098 | Avg Reward: 115.1
# Update 125 | Total Steps: 128000 | FPS: 20306 | Avg Reward: 136.6
# Update 130 | Total Steps: 133120 | FPS: 20501 | Avg Reward: 124.4
# Update 135 | Total Steps: 138240 | FPS: 20585 | Avg Reward: 115.6
# Update 140 | Total Steps: 143360 | FPS: 20531 | Avg Reward: 161.5
# Update 145 | Total Steps: 148480 | FPS: 20335 | Avg Reward: 129.1
# Update 150 | Total Steps: 153600 | FPS: 20368 | Avg Reward: 157.2
# Update 155 | Total Steps: 158720 | FPS: 20488 | Avg Reward: 170.0
# Update 160 | Total Steps: 163840 | FPS: 20605 | Avg Reward: 174.9
# Update 165 | Total Steps: 168960 | FPS: 20696 | Avg Reward: 145.4
# Update 170 | Total Steps: 174080 | FPS: 20822 | Avg Reward: 169.1
# Update 175 | Total Steps: 179200 | FPS: 20828 | Avg Reward: 185.4
# Update 180 | Total Steps: 184320 | FPS: 20854 | Avg Reward: 42.4
# Update 185 | Total Steps: 189440 | FPS: 20931 | Avg Reward: 87.4
# Update 190 | Total Steps: 194560 | FPS: 21030 | Avg Reward: 165.5
# Update 195 | Total Steps: 199680 | FPS: 21136 | Avg Reward: 152.0
# Update 200 | Total Steps: 204800 | FPS: 21176 | Avg Reward: 144.6
# Update 205 | Total Steps: 209920 | FPS: 21207 | Avg Reward: 147.0
# Update 210 | Total Steps: 215040 | FPS: 21300 | Avg Reward: 179.9
# Update 215 | Total Steps: 220160 | FPS: 21359 | Avg Reward: 201.5
# Update 220 | Total Steps: 225280 | FPS: 21355 | Avg Reward: 248.5
# Update 225 | Total Steps: 230400 | FPS: 21277 | Avg Reward: 275.3
# Update 230 | Total Steps: 235520 | FPS: 21312 | Avg Reward: 295.7
# Update 235 | Total Steps: 240640 | FPS: 21336 | Avg Reward: 292.6
# Update 240 | Total Steps: 245760 | FPS: 21420 | Avg Reward: 283.9
# Update 245 | Total Steps: 250880 | FPS: 21499 | Avg Reward: 284.1
# Update 250 | Total Steps: 256000 | FPS: 21515 | Avg Reward: 292.2
# Update 255 | Total Steps: 261120 | FPS: 21573 | Avg Reward: 281.0
# Update 260 | Total Steps: 266240 | FPS: 21554 | Avg Reward: 287.4
# Update 265 | Total Steps: 271360 | FPS: 21538 | Avg Reward: 286.1
# Update 270 | Total Steps: 276480 | FPS: 21592 | Avg Reward: 318.7
# Update 275 | Total Steps: 281600 | FPS: 21669 | Avg Reward: 342.7
# Update 280 | Total Steps: 286720 | FPS: 21676 | Avg Reward: 352.0
# Update 285 | Total Steps: 291840 | FPS: 21745 | Avg Reward: 330.5
# Update 290 | Total Steps: 296960 | FPS: 21770 | Avg Reward: 298.1
# Update 295 | Total Steps: 302080 | FPS: 21827 | Avg Reward: 317.2
# Update 300 | Total Steps: 307200 | FPS: 21824 | Avg Reward: 342.4
# Update 305 | Total Steps: 312320 | FPS: 21814 | Avg Reward: 361.9
# Update 310 | Total Steps: 317440 | FPS: 21793 | Avg Reward: 358.9
# Update 315 | Total Steps: 322560 | FPS: 21863 | Avg Reward: 355.0
# Update 320 | Total Steps: 327680 | FPS: 21926 | Avg Reward: 290.5
# Update 325 | Total Steps: 332800 | FPS: 21985 | Avg Reward: 305.4
# Update 330 | Total Steps: 337920 | FPS: 22032 | Avg Reward: 266.5
# Update 335 | Total Steps: 343040 | FPS: 22090 | Avg Reward: 296.5
# Update 340 | Total Steps: 348160 | FPS: 22138 | Avg Reward: 283.4
# Update 345 | Total Steps: 353280 | FPS: 22169 | Avg Reward: 325.4
# Update 350 | Total Steps: 358400 | FPS: 22166 | Avg Reward: 384.3
# Update 355 | Total Steps: 363520 | FPS: 22134 | Avg Reward: 429.0
# Update 360 | Total Steps: 368640 | FPS: 22191 | Avg Reward: 421.8
# Update 365 | Total Steps: 373760 | FPS: 22246 | Avg Reward: 426.6
# Update 370 | Total Steps: 378880 | FPS: 22287 | Avg Reward: 433.1
# Update 375 | Total Steps: 384000 | FPS: 22318 | Avg Reward: 420.4
# Update 380 | Total Steps: 389120 | FPS: 22353 | Avg Reward: 399.2
# Update 385 | Total Steps: 394240 | FPS: 22359 | Avg Reward: 401.1
# Update 390 | Total Steps: 399360 | FPS: 22312 | Avg Reward: 404.5

# %% [markdown]
# ## Conclusion
#
# Vectorization and Distributed RL are engineering tricks, but they are absolutely essential for making Reinforcement Learning viable in reality.
# By breaking out of the single-threaded loop, we solved CartPole to maximum efficiency using 150,000 steps in mere seconds.
#
# **But what happens if we don't have an environment to interact with at all?**
# What if we just have a static `.csv` file full of terrible logs recorded from a human driving a real car, and we can't physically spawn 8 clones to drive real cars without crashing and dying?
#
# That is the domain of **Offline RL** (Notebook 12)!
